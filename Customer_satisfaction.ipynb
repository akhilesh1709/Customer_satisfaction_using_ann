# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("customer_train.csv")

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# 2                                  2  ...                       5
# 3                                  5  ...                       2
# 4                                  3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 25 columns]

# %%
df.drop(["Unnamed: 0","id"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (103904, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
#  11  Online boarding                    103904 non-null  int64
#  12  Seat comfort                       103904 non-null  int64
#  13  Inflight entertainment             103904 non-null  int64
#  14  On-board service                   103904 non-null  int64
#  15  Leg room service                   103904 non-null  int64
#  16  Baggage handling                   103904 non-null  int64
#  17  Checkin service                    103904 non-null  int64
#  18  Inflight service                   103904 non-null  int64
#  19  Cleanliness                        103904 non-null  int64
#  20  Departure Delay in Minutes         103904 non-null  int64
#  21  Arrival Delay in Minutes           103594 non-null  float64
#  22  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 18.2+ MB

# %% [markdown]
# Handling missing values

# %%
df.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# dtype: int64

# %%
df['Arrival Delay in Minutes']=df['Arrival Delay in Minutes'].fillna(df['Arrival Delay in Minutes'].mode()[0])

# %%
df.isna().sum()
# Out:
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# Handling categorical data

# %%
cols = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

for col in cols:
    print(f"{col}:\n{df[col].value_counts()}\n")
# Out:
# Gender:
# Female    52727
# Male      51177
# Name: Gender, dtype: int64
#
# Customer Type:
# Loyal Customer       84923
# disloyal Customer    18981
# Name: Customer Type, dtype: int64
#
# Type of Travel:
# Business travel    71655
# Personal Travel    32249
# Name: Type of Travel, dtype: int64
#
# Class:
# Business    49665
# Eco         46745
# Eco Plus     7494
# Name: Class, dtype: int64
#
# satisfaction:
# neutral or dissatisfied    58879
# satisfied                  45025
# Name: satisfaction, dtype: int64

# %%
# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# %%
# Apply label encoding to each categorical column
categorical_columns = ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']
df[categorical_columns] = df[categorical_columns].apply(lambda col: label_encoder.fit_transform(col))

# %%
df.head()
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes  satisfaction
# 0                      18.0             0
# 1                       6.0             0
# 2                       0.0             1
# 3                       9.0             0
# 4                       0.0             1
#
# [5 rows x 23 columns]

# %% [markdown]
# Train Test split

# %%
X = df.drop('satisfaction',axis='columns')
y = df['satisfaction']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (83123, 22)

# %%
X_test.shape
# Out:
# (20781, 22)

# %%
len(X_train.columns)
# Out:
# 22

# %% [markdown]
# Training the model

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping

# %%
# Example model with dropout and early stopping
model = Sequential([
    Dense(22, input_shape=(22,), activation='relu'),
    Dense(15, activation='relu'),
    Dense(1, activation='sigmoid')
])

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)

# %%
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.7283 - accuracy: 0.7480
# Epoch 2/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.5040 - accuracy: 0.8117
# Epoch 3/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.4764 - accuracy: 0.8265
# Epoch 4/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.4676 - accuracy: 0.8281
# Epoch 5/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.4477 - accuracy: 0.8345
# Epoch 6/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.4219 - accuracy: 0.8419
# Epoch 7/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.4176 - accuracy: 0.8434
# Epoch 8/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.3987 - accuracy: 0.8483
# Epoch 9/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.3917 - accuracy: 0.8499
# Epoch 10/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.3963 - accuracy: 0.8499
# Epoch 11/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.3897 - accuracy: 0.8513
# Epoch 12/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.3806 - accuracy: 0.8536
# Epoch 13/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.3668 - accuracy: 0.8582
# Epoch 14/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.3646 - accuracy: 0.8597
# Epoch 15/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.3334 - accuracy: 0.8711
# Epoch 16/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.3190 - accuracy: 0.8756
# Epoch 17/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.2881 - accuracy: 0.8860
# Epoch 18/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.2798 - accuracy: 0.8885
# Epoch 19/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.2623 - accuracy: 0.8930
# Epoch 20/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.2376 - accuracy: 0.9040
# Epoch 21/100
# 2598/2598 [==============================] - 7s 3ms/step - loss: 0.2254 - accuracy: 0.9078
# Epoch 22/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.2223 - accuracy: 0.9086
# Epoch 23/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.2124 - accuracy: 0.9132
# Epoch 24/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.2115 - accuracy: 0.9126
# Epoch 25/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.2065 - accuracy: 0.9151
# Epoch 26/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.2042 - accuracy: 0.9164
# Epoch 27/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.2021 - accuracy: 0.9161
# Epoch 28/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.2038 - accuracy: 0.9151
# Epoch 29/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1937 - accuracy: 0.9200
# Epoch 30/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1945 - accuracy: 0.9185
# Epoch 31/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1951 - accuracy: 0.9196
# Epoch 32/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1913 - accuracy: 0.9201
# Epoch 33/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1905 - accuracy: 0.9202
# Epoch 34/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1869 - accuracy: 0.9222
# Epoch 35/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1888 - accuracy: 0.9216
# Epoch 36/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1836 - accuracy: 0.9236
# Epoch 37/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1894 - accuracy: 0.9219
# Epoch 38/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1844 - accuracy: 0.9242
# Epoch 39/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1815 - accuracy: 0.9239
# Epoch 40/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1826 - accuracy: 0.9238
# Epoch 41/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1837 - accuracy: 0.9236
# Epoch 42/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1811 - accuracy: 0.9251
# Epoch 43/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1792 - accuracy: 0.9254
# Epoch 44/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1778 - accuracy: 0.9257
# Epoch 45/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1808 - accuracy: 0.9245
# Epoch 46/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1780 - accuracy: 0.9253
# Epoch 47/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1770 - accuracy: 0.9250
# Epoch 48/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1768 - accuracy: 0.9259
# Epoch 49/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1751 - accuracy: 0.9263
# Epoch 50/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1742 - accuracy: 0.9268
# Epoch 51/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1756 - accuracy: 0.9267
# Epoch 52/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1770 - accuracy: 0.9261
# Epoch 53/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1758 - accuracy: 0.9258
# Epoch 54/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1735 - accuracy: 0.9270
# Epoch 55/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1717 - accuracy: 0.9280
# Epoch 56/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1734 - accuracy: 0.9266
# Epoch 57/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1721 - accuracy: 0.9275
# Epoch 58/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1736 - accuracy: 0.9262
# Epoch 59/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1706 - accuracy: 0.9282
# Epoch 60/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1728 - accuracy: 0.9268
# Epoch 61/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1715 - accuracy: 0.9276
# Epoch 62/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1704 - accuracy: 0.9283
# Epoch 63/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1709 - accuracy: 0.9275
# Epoch 64/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1707 - accuracy: 0.9277
# Epoch 65/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1697 - accuracy: 0.9283
# Epoch 66/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1708 - accuracy: 0.9276
# Epoch 67/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1689 - accuracy: 0.9282
# Epoch 68/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1695 - accuracy: 0.9283
# Epoch 69/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1669 - accuracy: 0.9290
# Epoch 70/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1683 - accuracy: 0.9286
# Epoch 71/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1678 - accuracy: 0.9286
# Epoch 72/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1668 - accuracy: 0.9286
# Epoch 73/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1654 - accuracy: 0.9289
# Epoch 74/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1653 - accuracy: 0.9296
# Epoch 75/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1663 - accuracy: 0.9288
# Epoch 76/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1657 - accuracy: 0.9290
# Epoch 77/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1623 - accuracy: 0.9301
# Epoch 78/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1631 - accuracy: 0.9300
# Epoch 79/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1648 - accuracy: 0.9296
# Epoch 80/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1629 - accuracy: 0.9298
# Epoch 81/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1627 - accuracy: 0.9306
# Epoch 82/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1614 - accuracy: 0.9304
# Epoch 83/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1598 - accuracy: 0.9310
# Epoch 84/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1608 - accuracy: 0.9307
# Epoch 85/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1587 - accuracy: 0.9321
# Epoch 86/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1601 - accuracy: 0.9303
# Epoch 87/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1571 - accuracy: 0.9327
# Epoch 88/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1566 - accuracy: 0.9329
# Epoch 89/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1587 - accuracy: 0.9317
# Epoch 90/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1567 - accuracy: 0.9319
# Epoch 91/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1572 - accuracy: 0.9323
# Epoch 92/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1546 - accuracy: 0.9332
# Epoch 93/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1554 - accuracy: 0.9328
# Epoch 94/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1548 - accuracy: 0.9328
# Epoch 95/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1537 - accuracy: 0.9340
# Epoch 96/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1536 - accuracy: 0.9340
# Epoch 97/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1543 - accuracy: 0.9338
# Epoch 98/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1513 - accuracy: 0.9346
# Epoch 99/100
# 2598/2598 [==============================] - 5s 2ms/step - loss: 0.1509 - accuracy: 0.9350
# Epoch 100/100
# 2598/2598 [==============================] - 6s 2ms/step - loss: 0.1519 - accuracy: 0.9350

# %%
model.evaluate(X_test, y_test)
# Out:
# 650/650 [==============================] - 1s 1ms/step - loss: 0.1431 - accuracy: 0.9408
# [0.14309296011924744, 0.9407631754875183]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# 650/650 [==============================] - 1s 1ms/step
# array([[0.00153849],
#        [0.00410671],
#        [0.98612493],
#        [0.997082  ],
#        [0.99683064]], dtype=float32)

# %%
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)

# %%
y_pred[:10]
# Out:
# [0, 0, 1, 1, 1, 1, 1, 0, 1, 1]

# %%
y_test[:10]
# Out:
# 1751      0
# 95684     0
# 71802     1
# 89601     1
# 58769     1
# 103066    1
# 35560     1
# 42519     0
# 100365    1
# 66075     1
# Name: satisfaction, dtype: int64

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     11778
#            1       0.96      0.90      0.93      9003
#
#     accuracy                           0.94     20781
#    macro avg       0.94      0.94      0.94     20781
# weighted avg       0.94      0.94      0.94     20781
